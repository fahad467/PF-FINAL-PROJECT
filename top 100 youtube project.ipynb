# %% [markdown]
# ## Top 100 Youtubers Ranking

# %% [markdown]
# # Name
# Syed Fahad Shabbir
# # Roll No
# 040
# ## GitHub Link
# https://github.com/fahad467/PF-FINAL-PROJECT.git

# %%
import pandas as pd

# %%
df = pd.read_csv("youtube data.csv")

# %%
df.shape
# Out:
# (101, 6)

# %% [markdown]
# ## Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ranking      100 non-null    float64
#  1   Username     100 non-null    object
#  2   Subscribers  100 non-null    object
#  3   Uploads      100 non-null    object
#  4   Views        100 non-null    object
#  5   Country      94 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 4.9+ KB

# %%
column = list(df.columns)
column
# Out:
# ['Ranking', 'Username', 'Subscribers', 'Uploads', 'Views', 'Country']

# %% [markdown]
# #### Checking values

# %%
df.isna().sum()
# Out:
# Ranking        1
# Username       1
# Subscribers    1
# Uploads        1
# Views          1
# Country        7
# dtype: int64

# %% [markdown]
# #### Cleaning a set

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of      Ranking                  Username Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M      838   66,853,633,536
# 1        2.0                  T-Series        281M   22,313  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 3        4.0            Youtube Movies        185M        0                0
# 4        5.0                 Set India        180M  148,727  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M    1,714    8,180,068,059
# 97      98.0                Katy Perry       45.6M      170   27,616,850,074
# 98      99.0             Speed Records       45.5M   11,880   30,587,436,800
# 99     100.0                     Zhong       45.5M    1,861   17,998,163,730
# 100      NaN                       NaN         NaN      NaN              NaN
#
#     Country
# 0        US
# 1        IN
# 2        US
# 3       NaN
# 4        IN
# ..      ...
# 96       BR
# 97       US
# 98       IN
# 99       US
# 100     NaN
#
# [101 rows x 6 columns]>

# %%
df.dropna(inplace=True)

# %%
df.fillna(40)
# Out:
#      Ranking                  Username Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M      838   66,853,633,536
# 1        2.0                  T-Series        281M   22,313  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 3        4.0            Youtube Movies        185M        0                0
# 4        5.0                 Set India        180M  148,727  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M    1,714    8,180,068,059
# 97      98.0                Katy Perry       45.6M      170   27,616,850,074
# 98      99.0             Speed Records       45.5M   11,880   30,587,436,800
# 99     100.0                     Zhong       45.5M    1,861   17,998,163,730
# 100     40.0                        40          40       40               40
#
#     Country
# 0        US
# 1        IN
# 2        US
# 3        40
# 4        IN
# ..      ...
# 96       BR
# 97       US
# 98       IN
# 99       US
# 100      40
#
# [101 rows x 6 columns]

# %% [markdown]
# ### Replace Specific Columns

# %%
df['Subscribers'].fillna(20)
# Out:
# 0      336M
# 1      281M
# 2      186M
# 4      180M
# 5      129M
#       ...
# 95      46M
# 96      46M
# 97    45.6M
# 98    45.5M
# 99    45.5M
# Name: Subscribers, Length: 94, dtype: object

# %%
# taking out the avg of uploads


mean_rankings = df['Ranking'].mean()
print(mean_rankings)
# Out:
# 52.56382978723404

# %%
df['Country'].mode() # common
# Out:
# 0    IN
# Name: Country, dtype: object

# %%
# middle(doesn't calculate the middle one if any value is non numerical or commas are present)
median_uploads = df['Uploads'].median()  
print(median_uploads)
# Out:
# 508.0

# %% [markdown]
# ## Data Duplication

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 4     False
# 5     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 94, dtype: bool

# %%
#pd.set_option("display.max_rows",None)
#pd.set_option("display.max_columns",None)
#df.duplicated()

# %%
df.drop_duplicates()
# Out:
#      Ranking                  Username Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M      838   66,853,633,536
# 1        2.0                  T-Series        281M   22,313  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 3        4.0            Youtube Movies        185M        0                0
# 4        5.0                 Set India        180M  148,727  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M    1,714    8,180,068,059
# 97      98.0                Katy Perry       45.6M      170   27,616,850,074
# 98      99.0             Speed Records       45.5M   11,880   30,587,436,800
# 99     100.0                     Zhong       45.5M    1,861   17,998,163,730
# 100      NaN                       NaN         NaN      NaN              NaN
#
#     Country
# 0        US
# 1        IN
# 2        US
# 3       NaN
# 4        IN
# ..      ...
# 96       BR
# 97       US
# 98       IN
# 99       US
# 100     NaN
#
# [101 rows x 6 columns]

# %%
df.describe()
# Out:
#           Ranking    col
# count  100.000000  101.0
# mean    50.500000    6.0
# std     29.011492    0.0
# min      1.000000    6.0
# 25%     25.750000    6.0
# 50%     50.500000    6.0
# 75%     75.250000    6.0
# max    100.000000    6.0

# %%
df.describe(include = "all").iloc[[0,5]] # include all and give the index and position
# Out:
#           Ranking Username Subscribers Uploads Views Country
# count  100.000000      100         100     100   100      94
# std     29.011492      NaN         NaN     NaN   NaN     NaN

# %%
df.describe(include = "all").loc[["min","max"]] # it can include all the values and tell the "max or min"
# Out:
#      Ranking Username Subscribers Uploads Views Country
# min      1.0      NaN         NaN     NaN   NaN     NaN
# max    100.0      NaN         NaN     NaN   NaN     NaN

# %% [markdown]
# ## Adding a Column

# %%
df['col'] = 6 # just adding a column
df
# Out:
#      Ranking                  Username Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M      838   66,853,633,536
# 1        2.0                  T-Series        281M   22,313  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 3        4.0            Youtube Movies        185M        0                0
# 4        5.0                 Set India        180M  148,727  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M    1,714    8,180,068,059
# 97      98.0                Katy Perry       45.6M      170   27,616,850,074
# 98      99.0             Speed Records       45.5M   11,880   30,587,436,800
# 99     100.0                     Zhong       45.5M    1,861   17,998,163,730
# 100      NaN                       NaN         NaN      NaN              NaN
#
#     Country  col
# 0        US    6
# 1        IN    6
# 2        US    6
# 3       NaN    6
# 4        IN    6
# ..      ...  ...
# 96       BR    6
# 97       US    6
# 98       IN    6
# 99       US    6
# 100     NaN    6
#
# [101 rows x 7 columns]

# %%
inplace=True

# %% [markdown]
# ## Removing a Column

# %%
df.drop(columns = ['col'], inplace = True, errors= "ignore")
df
# Out:
#      Ranking                  Username Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M      838   66,853,633,536
# 1        2.0                  T-Series        281M   22,313  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 3        4.0            Youtube Movies        185M        0                0
# 4        5.0                 Set India        180M  148,727  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M    1,714    8,180,068,059
# 97      98.0                Katy Perry       45.6M      170   27,616,850,074
# 98      99.0             Speed Records       45.5M   11,880   30,587,436,800
# 99     100.0                     Zhong       45.5M    1,861   17,998,163,730
# 100      NaN                       NaN         NaN      NaN              NaN
#
#     Country
# 0        US
# 1        IN
# 2        US
# 3       NaN
# 4        IN
# ..      ...
# 96       BR
# 97       US
# 98       IN
# 99       US
# 100     NaN
#
# [101 rows x 6 columns]

# %% [markdown]
# ## Adding a row

# %%
data = {
    'Rank': [1, 2, 3], 
    'Channel Name': ['T-Series', 'Cocomelon', 'MrBeast'],
    'Subscribers (Millions)': [250, 160, 150],
    'Total Views (Billions)': [230, 140, 25], 
    'Videos Uploaded': [19000, 800, 750 ], 
    'Country': ['India', 'USA', 'USA'],  
    'Category': ['Music', 'Kids', 'Entertainment']  
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Rank Channel Name  Subscribers (Millions)  Total Views (Billions)  \
# 0     1     T-Series                     250                     230
# 1     2    Cocomelon                     160                     140
# 2     3      MrBeast                     150                      25
#
#    Videos Uploaded Country       Category
# 0            19000   India          Music
# 1              800     USA           Kids
# 2              750     USA  Entertainment

# %% [markdown]
# ## Removing a row

# %%
df.drop(1,inplace=True)
df
# Out:
#    Rank Channel Name  Subscribers (Millions)  Total Views (Billions)  \
# 0     1     T-Series                     250                     230
# 2     3      MrBeast                     150                      25
#
#    Videos Uploaded Country       Category
# 0            19000   India          Music
# 2              750     USA  Entertainment

# %% [markdown]
# ## Slicing in code

# %%
df[2:20:2]
# Out:
#     Ranking                  Username Subscribers  Uploads            Views  \
# 2       3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 4       5.0                 Set India        180M  148,727  172,709,029,653
# 6       7.0           Kids Diana Show        128M    1,282  108,987,929,584
# 8       9.0                     Music        121M        0                0
# 10     11.0                 PewDiePie        110M    4,800   29,453,929,047
# 12     13.0              Stokes Twins        102M      335   16,139,307,959
# 14     15.0                  Sony SAB       97.7M   94,136  123,172,828,384
# 16     17.0                 ChuChu Tv       94.3M      832   53,265,415,943
# 18     19.0                    Zee TV       86.2M  190,672   97,566,987,807
#
#    Country
# 2       US
# 4       IN
# 6       US
# 8      NaN
# 10      JP
# 12      US
# 14      IN
# 16      IN
# 18      IN

# %%
df[['Username']][4:12]
# Out:
#              Username
# 4           Set India
# 5         Vlad & Niki
# 6     Kids Diana Show
# 7         Like Nastya
# 8               Music
# 9   Zee Music Company
# 10          PewDiePie
# 11                WWE

# %% [markdown]
# ## Flowcharts

# %%
df['Country'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
df['Subscribers'].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Subscribers'>

# %%
df['Uploads'].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
df['Views'].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df['Username'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df['Ranking'].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Ranking'>

# %%
df['Country'].value_counts().plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df['Subscribers'].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Data Aggretion

# %%
# Aggregating numeric columns
numeric_aggregates = df.select_dtypes(include='number').agg(['sum', 'min',])
print(numeric_aggregates)
# Out:
#      Ranking
# sum   5050.0
# min      1.0

# %% [markdown]
# ### Sum

# %%
df['Ranking'].sum()
# Out:
# 5050.0

# %% [markdown]
# ## Std (Standard Deviation)

# %%
df['Ranking'].std()
# Out:
# 29.011491975882016

# %% [markdown]
# ## var() -- Variance Calculation

# %%
df['Ranking'].var()
# Out:
# 841.6666666666666

# %% [markdown]
# ## Data Preprocessing

# %%
df.isnull().sum() # it only shows the empty values and sum on dataset
# Out:
# Ranking        1
# Username       1
# Subscribers    1
# Uploads        1
# Views          1
# Country        7
# dtype: int64

# %% [markdown]
# #### rename() Rename Columns

# %%
df.rename(columns={'Username':'Name'}, inplace=True)
df
# Out:
#      Ranking                      Name Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M      838   66,853,633,536
# 1        2.0                  T-Series        281M   22,313  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 3        4.0            Youtube Movies        185M        0                0
# 4        5.0                 Set India        180M  148,727  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M    1,714    8,180,068,059
# 97      98.0                Katy Perry       45.6M      170   27,616,850,074
# 98      99.0             Speed Records       45.5M   11,880   30,587,436,800
# 99     100.0                     Zhong       45.5M    1,861   17,998,163,730
# 100      NaN                       NaN         NaN      NaN              NaN
#
#     Country
# 0        US
# 1        IN
# 2        US
# 3       NaN
# 4        IN
# ..      ...
# 96       BR
# 97       US
# 98       IN
# 99       US
# 100     NaN
#
# [101 rows x 6 columns]

# %% [markdown]
# ## Data Saving

# %%
df = pd.read_csv("youtube data.csv")

# Save the DataFrame to an Excel file
df.to_excel("project.xlsx", index=False)
